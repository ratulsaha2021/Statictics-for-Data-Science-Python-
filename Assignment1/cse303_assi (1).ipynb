# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# JME COUNTRY ESTIMATES MAY2022 (SURVEY ESTIMATES)
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/CSE303/12.csv', encoding = "Windows-1252")
df.head()
# Out:
#   ï»¿ISO code Country and areas Survey year  Year* United Nations Region  \
# 0         AFG       AFGHANISTAN        1997   1997                  Asia
# 1         AFG       AFGHANISTAN        2004   2004                  Asia
# 2         AFG       AFGHANISTAN        2013   2013                  Asia
# 3         AFG       AFGHANISTAN        2018   2018                  Asia
# 4         ALB           ALBANIA     1996-98   1997                Europe
#
#   United Nations Sub-Region                      SDG Region UNICEF Region  \
# 0             Southern Asia  Central Asia and Southern Asia            SA
# 1             Southern Asia  Central Asia and Southern Asia            SA
# 2             Southern Asia  Central Asia and Southern Asia            SA
# 3             Southern Asia  Central Asia and Southern Asia            SA
# 4           Southern Europe     Northern America and Europe           ECA
#
#   UNICEF Sub-Region WHO Region  ... Stunting Stunting Footnote  \
# ...

# %%
#plotting of dataset.head()
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/CSE303/12.csv', encoding = "Windows-1252")
df.head().plot()
plt.show()

# %%
df.tail()
# Out:
#      ï»¿ISO code Country and areas Survey year  Year* United Nations Region  \
# 1030         ZWE          ZIMBABWE        2009   2009                Africa
# 1031         ZWE          ZIMBABWE     2010-11   2010                Africa
# 1032         ZWE          ZIMBABWE        2014   2014                Africa
# 1033         ZWE          ZIMBABWE        2015   2015                Africa
# 1034         ZWE          ZIMBABWE        2019   2019                Africa
#
#      United Nations Sub-Region          SDG Region UNICEF Region  \
# 1030            Eastern Africa  Sub-Saharan Africa           SSA
# 1031            Eastern Africa  Sub-Saharan Africa           SSA
# 1032            Eastern Africa  Sub-Saharan Africa           SSA
# 1033            Eastern Africa  Sub-Saharan Africa           SSA
# 1034            Eastern Africa  Sub-Saharan Africa           SSA
#
#      UNICEF Sub-Region WHO Region  ... Stunting Stunting Footnote  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 36 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ï»¿ISO code                       1035 non-null   object
#  1   Country and areas                 1035 non-null   object
#  2   Survey year                       1035 non-null   object
#  3   Year*                             1035 non-null   int64
#  4   United Nations Region             1035 non-null   object
#  5   United Nations Sub-Region         1035 non-null   object
#  6   SDG Region                        1035 non-null   object
#  7   UNICEF Region                     1023 non-null   object
#  8   UNICEF Sub-Region                 1023 non-null   object
#  9   WHO Region                        1027 non-null   object
#  10  World Bank Income Classification  1014 non-null   object
# ...

# %% [markdown]
# The above result shows, there are 1034 rows and 36 Columns.

# %%
#stunting_wasting_overweight
import pandas as pd
dff = pd.read_csv('/content/drive/MyDrive/CSE303/stun_was_over_database.csv')
dff.head()
# Out:
#    Unnamed: 0    ISO Countries and areas UNICEF Regions Survey Years   Year*   \
# 0         NaN    NaN                 NaN            NaN          NaN      NaN
# 1         3.0   AFG         Afghanistan             SA          2013   2013.0
# 2      3076.0   AFG         Afghanistan             SA          2018   2018.0
# 3         5.0   ALB             Albania           EECA          2000   2000.0
# 4         6.0   ALB             Albania           EECA          2005   2005.0
#
#   Short Source                                        Full Source  \
# 0          NaN                                                NaN
# 1          NNS         Afghanistan National Nutrition Survey 2013
# 2        Other                     Afghanistan Health Survey 2018
# 3         MICS  Multiple indicator cluster survey report Alban...
# 4         MICS  Albania multiple indicator cluster survey 2005...
#
#       Latest Estimate Estimate Type            Wasted Only  \
# ...

# %%
dff.tail()
# Out:
#      Unnamed: 0    ISO Countries and areas UNICEF Regions Survey Years  \
# 627       789.0   ZWE            Zimbabwe            ESA          2009
# 628       790.0   ZWE            Zimbabwe            ESA       2010-11
# 629       791.0   ZWE            Zimbabwe            ESA          2014
# 630       822.0   ZWE            Zimbabwe            ESA          2015
# 631      2445.0   ZWE            Zimbabwe            ESA          2019
#
#       Year*  Short Source                                        Full Source  \
# 627   2009.0         MICS  Zimbabwe multiple indicator monitoring survey ...
# 628   2010.0          DHS  Zimbabwe demographic and health survey 2010-11...
# 629   2014.0         MICS  Zimbabwe Multiple Indicator Cluster Survey 201...
# 630   2015.0          DHS  Zimbabwe Demographic and Health Survey 2015: F...
# 631   2019.0         MICS  Zimbabwe Multiple Indicator  Cluster Survey 20...
#
#         Latest Estimate Estimate Type Wasted Only Wasted and Stunted  \
# ...

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 632 entries, 0 to 631
# Data columns (total 16 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               631 non-null    float64
#  1   ISO                                      631 non-null    object
#  2   Countries and areas                      631 non-null    object
#  3   UNICEF Regions                           631 non-null    object
#  4   Survey Years                             631 non-null    object
#  5    Year*                                   631 non-null    float64
#  6   Short Source                             631 non-null    object
#  7   Full Source                              631 non-null    object
#  8   Latest Estimate                          631 non-null    object
#  9   Estimate Type                            631 non-null    object
# ...
