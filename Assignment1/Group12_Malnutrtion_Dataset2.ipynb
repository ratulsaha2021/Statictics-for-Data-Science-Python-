# %%
#Malnutrition across the globe
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/country-wise-average.csv', encoding = "Windows-1252")
df
# Out:
#                                 Country  Income Classification  \
# 0                           AFGHANISTAN                    0.0
# 1                               ALBANIA                    2.0
# 2                               ALGERIA                    2.0
# 3                                ANGOLA                    1.0
# 4                             ARGENTINA                    2.0
# ..                                  ...                    ...
# 147  VENEZUELA (BOLIVARIAN REPUBLIC OF)                    2.0
# 148                            VIET NAM                    1.0
# 149                               YEMEN                    0.0
# 150                              ZAMBIA                    1.0
# 151                            ZIMBABWE                    1.0
#
#      Severe Wasting    Wasting  Overweight   Stunting  Underweight  \
# 0          3.033333  10.350000    5.125000  47.775000    30.375000
# 1          4.075000   7.760000   20.800000  24.160000     7.700000
# ...

# %%
df.tail()
# Out:
#                                 Country  Income Classification  \
# 147  VENEZUELA (BOLIVARIAN REPUBLIC OF)                    2.0
# 148                            VIET NAM                    1.0
# 149                               YEMEN                    0.0
# 150                              ZAMBIA                    1.0
# 151                            ZIMBABWE                    1.0
#
#      Severe Wasting    Wasting  Overweight   Stunting  Underweight  \
# 147             NaN   4.333333    5.409524  16.957143     4.242857
# 148        2.331250   8.661905    3.317647  34.922727    22.918182
# 149        5.300000  15.242857    4.842857  51.900000    37.785714
# 150        2.042857   5.542857    7.228571  48.137500    17.885714
# 151        1.388889   4.166667    5.788889  30.455556    10.710000
#
#      U5 Population ('000s)
# 147            2787.800095
# 148            7507.220273
# 149            3269.476000
# 150            2083.494500
# 151            1912.450400

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                152 non-null    object
#  1   Income Classification  152 non-null    float64
#  2   Severe Wasting         140 non-null    float64
#  3   Wasting                150 non-null    float64
#  4   Overweight             149 non-null    float64
#  5   Stunting               151 non-null    float64
#  6   Underweight            150 non-null    float64
#  7   U5 Population ('000s)  152 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 9.6+ KB
# None

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/malnutrition-estimates.csv', encoding = "Windows-1252")
df
# Out:
#      Unnamed: 0 ISO code      Country Survey Year  Year  \
# 0             0      AFG  AFGHANISTAN        1997  1997
# 1             1      AFG  AFGHANISTAN        2004  2004
# 2             2      AFG  AFGHANISTAN        2013  2013
# 3             3      AFG  AFGHANISTAN        2018  2018
# 4             4      ALB      ALBANIA     1996-98  1997
# ..          ...      ...          ...         ...   ...
# 919         919      ZWE     ZIMBABWE        2009  2009
# 920         920      ZWE     ZIMBABWE     2010-11  2010
# 921         921      ZWE     ZIMBABWE        2014  2014
# 922         922      ZWE     ZIMBABWE        2015  2015
# 923         923      ZWE     ZIMBABWE        2019  2019
#
#      Income Classification  LDC  LIFD  LLDC or SID2 Survey Sample (N)  \
# 0                        0  1.0   1.0           1.0             4,846
# 1                        0  1.0   1.0           1.0               946
# 2                        0  1.0   1.0           1.0         44,26,469
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0 ISO code   Country Survey Year  Year  Income Classification  \
# 919         919      ZWE  ZIMBABWE        2009  2009                      1
# 920         920      ZWE  ZIMBABWE     2010-11  2010                      1
# 921         921      ZWE  ZIMBABWE        2014  2014                      1
# 922         922      ZWE  ZIMBABWE        2015  2015                      1
# 923         923      ZWE  ZIMBABWE        2019  2019                      1
#
#      LDC  LIFD  LLDC or SID2 Survey Sample (N)  Severe Wasting  Wasting  \
# 919  0.0   1.0           1.0             6,196             0.5      2.4
# 920  0.0   1.0           1.0             5,414             0.8      3.2
# 921  0.0   1.0           1.0             9,591             0.7      3.2
# 922  0.0   1.0           1.0             6,380             1.1      3.3
# 923  0.0   1.0           1.0             5,978             0.3      2.9
#
#      Overweight  Stunting  Underweight Notes  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 ISO code      Country Survey Year  Year  Income Classification  \
# 0           0      AFG  AFGHANISTAN        1997  1997                      0
# 1           1      AFG  AFGHANISTAN        2004  2004                      0
# 2           2      AFG  AFGHANISTAN        2013  2013                      0
# 3           3      AFG  AFGHANISTAN        2018  2018                      0
# 4           4      ALB      ALBANIA     1996-98  1997                      2
#
#    LDC  LIFD  LLDC or SID2 Survey Sample (N)  Severe Wasting  Wasting  \
# 0  1.0   1.0           1.0             4,846             NaN     18.2
# 1  1.0   1.0           1.0               946             3.5      8.6
# 2  1.0   1.0           1.0         44,26,469             4.0      9.5
# 3  1.0   1.0           1.0               NaN             1.6      5.1
# 4  0.0   0.0           0.0             7,642             NaN      8.1
#
#    Overweight  Stunting  Underweight                Notes  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 924 entries, 0 to 923
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             924 non-null    int64
#  1   ISO code               924 non-null    object
#  2   Country                924 non-null    object
#  3   Survey Year            924 non-null    object
#  4   Year                   924 non-null    int64
#  5   Income Classification  924 non-null    int64
#  6   LDC                    924 non-null    float64
#  7   LIFD                   924 non-null    float64
#  8   LLDC or SID2           924 non-null    float64
#  9   Survey Sample (N)      861 non-null    object
#  10  Severe Wasting         696 non-null    float64
#  11  Wasting                877 non-null    float64
#  12  Overweight             788 non-null    float64
#  13  Stunting               887 non-null    float64
# ...

# %%
#Plot for country wise average data
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/country-wise-average.csv')

df.plot()

plt.show()

# %%
#Histogram for average severe wasting of contries
df["Severe Wasting"].plot(kind = 'hist')
